# %% [markdown]
# <a href="https://colab.research.google.com/github/muskanalirizvi/Practice-sklearn/blob/main/Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('wine_data.csv')
df = df.iloc[:,:3]
df.columns = ['ClassLabel', 'Alcohol', 'MalicAcid']
df.head(5)
# Out:
#    ClassLabel  Alcohol  MalicAcid
# 0           1    13.20       1.78
# 1           1    13.16       2.36
# 2           1    14.37       1.95
# 3           1    13.24       2.59
# 4           1    14.20       1.76

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['ClassLabel'], axis=1)
y = df['ClassLabel']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((141, 2), (36, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[0.33870968, 0.48023715],
#        [0.31989247, 0.10869565],
#        [1.        , 0.19565217],
#        [0.16397849, 0.26086957],
#        [0.5188172 , 0.53557312],
#        [0.26075269, 0.53162055],
#        [0.55913978, 0.05335968],
#        [0.51075269, 0.40909091],
#        [0.54301075, 0.61660079],
#        [0.76075269, 0.12055336],
#        [0.87903226, 0.23320158],
#        [0.27150538, 0.70355731],
#        [0.54301075, 0.1798419 ],
#        [0.35215054, 0.33794466],
#        [0.34946237, 0.04940711],
#        [0.28225806, 0.21541502],
#        [0.66397849, 0.21146245],
#        [0.53763441, 0.03162055],
#        [0.72580645, 0.15019763],
#        [0.55107527, 0.62450593],
#        [0.37365591, 0.72924901],
#        [0.26075269, 0.03557312],
#        [0.15860215, 0.24703557],
#        [0.48924731, 0.5       ],
#        [0.34946237, 0.07114625],
#        [0.71505376, 0.49802372],
#        [0.37365591, 0.17193676],
#        [0.68010753, 0.19565217],
# ...

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns = x_test.columns)

# %%
x_train_scaled.describe()
# Out:
#           Alcohol   MalicAcid
# count  141.000000  141.000000
# mean     0.512106    0.322947
# std      0.220273    0.228986
# min      0.000000    0.000000
# 25%      0.338710    0.169960
# 50%      0.510753    0.223320
# 75%      0.696237    0.480237
# max      1.000000    1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(x_train['Alcohol'], x_train['MalicAcid'],c=y_train)
ax1.set_title("Before Scaling")
ax2.scatter(x_train_scaled['Alcohol'], x_train_scaled['MalicAcid'],c=y_train)
ax2.set_title("After Scaling")
plt.show()
